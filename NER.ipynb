# %%
# pip install -U spacy
# python -m spacy download en_core_web_sm
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_lg")

# Process whole documents
text = "Marshmellos Coca-Cola"
text = "24 oz Pepsi Fountain drink"
# text = "BVC - Coke Cherry"
# text = "BVC - Can Dr Pepper 12oz"
# text = "Bottle Canada Dry Ginger Ale 20oz"
# text = "I recently bought an Apple MacBook Pro and an iPhone 13 from the Apple store."
text = "Pepsi Max"
# text = (text.lower())
doc = nlp(text)


# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
    

import nltk
import nltk
from nltk.corpus import stopwords

stop_words = stopwords.words('english')

wordsList = nltk.word_tokenize(text)

# removing stop words from wordList
wordsList = [w for w in wordsList if not w in stop_words]

#  Using a Tagger. Which is part-of-speech
# tagger or POS-tagger.
tagged = nltk.pos_tag(wordsList)
tagged
# Out:
# Pepsi Max ORG
# [('Pepsi', 'NNS'), ('Max', 'NNP')]

# %%
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
# Out:
# Noun phrases: ['canada', 'ginger ale', '20oz']

# %%
# Out:
# [('pepsi', 'NNS'), ('max', 'NN')]

# %%
# pip install -U spacy
# python -m spacy download en_core_web_sm
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("marshmellos")
doc = nlp(text)


# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)

# %%
import pandas as pd

df = pd.read_csv("./carbonated_soft_drinks.csv")
df['item_name'] = df.item_name.apply(lambda x: x.lower())

# %%
import nltk
from nltk.corpus import stopwords

stop_words = stopwords.words('english')

# %%
nltk.words

# %%
any(chr.isdigit() for chr in "hello wordls 1")
# Out:
# True

# %%
texts = []
for i in df.item_name.values.tolist():
    texts.extend([j for j in i.split(" ") if j and j not in stop_words and not any(chr.isdigit() for chr in j)])
texts = list(set(texts))

# %%
texts
# Out:
# ['bvc',
#  'strongest',
#  'grapefr',
#  'lime,',
#  'dewfrost',
#  'ok',
#  'soda/combos',
#  'rhuba',
#  'card.',
#  'foam',
#  'especial',
#  'melo',
#  'canadda',
#  'verite',
#  "-barq's",
#  'marshmellos',
#  'pu',
#  'arizona',
#  'pomagranite',
#  'coke/',
#  'pack',
#  'mist.',
#  'chef',
#  'dogfish',
#  'co,e',
#  'romaine',
#  'bvc-grape',
#  '-vanilla',
#  'pills',
#  'slices',
#  'canda',
#  'time',
#  'zsunkist',
#  'mashu',
#  'tropsun',
#  'concession',
#  'brj',
#  'chico',
#  'peps',
#  'youth',
#  'pepsizero',
#  'orangeseltzer',
#  'la',
#  'twists',
#  'deal',
#  'mocknorita',
#  'discount',
#  'drin',
#  'mountaindew',
#  'gourmet',
#  'kicks',
#  'kick',
#  'rise-pomegrante',
#  'dietpeachsnapple',
#  'weinhards',
#  'aunty',
#  'selfserve',
#  "flamin'hot",
#  'andrade',
#  'strawb',
#  'drp',
#  'top',
#  'abmc',
#  'neli',
#  'cider',
#  'manzanita',
#  'trop.',
#  'pak,',
#  'sale',
#  'brands',
#  'fanta_pina',
#  'artois.',
#  'braundenburg',
# ...
